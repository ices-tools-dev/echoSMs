# %% [markdown]
# ## Tutorial
# <a target="_blank" href="https://colab.research.google.com/github/ices-tools-dev/echoSMs/blob/main/docs/tutorial.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# This notebook provides an introductory tutorial for echoSMs.

# %%
# !pip install matplotlib echosms
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: echosms in /usr/local/lib/python3.11/dist-packages (0.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: mapply in /usr/local/lib/python3.11/dist-packages (from echosms) (0.1.27)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from echosms) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from echosms) (1.13.1)
# Requirement already satisfied: spheroidalwavefunctions in /usr/local/lib/python3.11/dist-packages (from echosms) (0.1.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from echosms) (4.67.1)
# Requirement already satisfied: trimesh in /usr/local/lib/python3.11/dist-packages (from echosms) (4.6.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (from echosms) (2025.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pathos>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from mapply->echosms) (0.3.3)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from mapply->echosms) (0.70.17)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from mapply->echosms) (5.9.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->echosms) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->echosms) (2025.1)
# Requirement already satisfied: ppft>=1.7.6.9 in /usr/local/lib/python3.11/dist-packages (from pathos>=0.3.1->mapply->echosms) (1.7.6.9)
# Requirement already satisfied: dill>=0.3.9 in /usr/local/lib/python3.11/dist-packages (from pathos>=0.3.1->mapply->echosms) (0.3.9)
# Requirement already satisfied: pox>=0.3.5 in /usr/local/lib/python3.11/dist-packages (from pathos>=0.3.1->mapply->echosms) (0.3.5)

# %% [markdown]
# ## Imports
#
# We import the modal series solution model from echoSMs and the benchmark data and reference models.

# %%
from echosms import MSSModel, BenchmarkData, ReferenceModels
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Reference models
# The reference models in the Jech et al (2015) paper are available in the echoSMs package:

# %%
rm = ReferenceModels()
print('Available reference models are:\n')
print('\n'.join(rm.names()))
# Out:
# Available reference models are:
#
# fixed rigid sphere
# pressure release sphere
# gas filled sphere
# weakly scattering sphere
# spherical fluid shell with pressure release interior
# spherical fluid shell with gas interior
# spherical fluid shell with weakly scattering interior
# fixed rigid prolate spheroid
# pressure release prolate spheroid
# gas filled prolate spheroid
# weakly scattering prolate spheroid
# fixed rigid finite cylinder
# pressure release finite cylinder
# gas filled finite cylinder
# weakly scattering finite cylinder
# WC20 calibration sphere
# WC21 calibration sphere
# WC22 calibration sphere
# WC25 calibration sphere
# WC38.1 calibration sphere
# WC57.2 calibration sphere
# WC60 calibration sphere
# WC64 calibration sphere
# Cu10.3 calibration sphere
# Cu13.7 calibration sphere
# Cu23 calibration sphere
# Cu32 calibration sphere
# Cu32.1 calibration sphere
# Cu42 calibration sphere
# Cu45 calibration sphere
# Cu60 calibration sphere
# Cu63 calibration sphere
# Cu64 calibration sphere

# %% [markdown]
# ## Benchmark results
# Likewise, the results from the benchmark model runs in the Jech et al (2015) paper are available in the echoSMs package.

# %%
bm = BenchmarkData()
bmf = bm.freq_as_dataframe()
bmf
# Out:
#            fixed rigid sphere  pressure release sphere  gas filled sphere  \
# frequency
# 12000.0                -54.44                   -42.29             -42.34
# 14000.0                -52.20                   -42.92             -42.93
# 16000.0                -50.40                   -43.52             -43.52
# 18000.0                -48.96                   -44.02             -44.03
# 20000.0                -47.85                   -44.39             -44.40
# ...                       ...                      ...                ...
# 392000.0               -45.96                   -46.00             -46.03
# 394000.0               -45.86                   -46.00             -45.96
# 396000.0               -45.80                   -46.00             -46.07
# 398000.0               -45.80                   -46.00             -45.96
# 400000.0               -45.84                   -46.00             -46.05
#
#            weakly scattering sphere  \
# frequency
# 12000.0                     -103.95
# 14000.0                     -101.62
# 16000.0                      -99.69
# 18000.0                      -98.10
# 20000.0                      -96.79
# ...                             ...
# 392000.0                    -103.61
# 394000.0                    -100.25
# 396000.0                     -98.03
# 398000.0                     -96.47
# 400000.0                     -95.37
#
#            spherical fluid shell with pressure release interior  \
# frequency
# 12000.0                                               -42.83
# 14000.0                                               -43.40
# 16000.0                                               -43.96
# 18000.0                                               -44.49
# 20000.0                                               -44.94
# ...                                                      ...
# 392000.0                                              -46.91
# 394000.0                                              -46.91
# 396000.0                                              -46.91
# 398000.0                                              -46.91
# 400000.0                                              -46.91
#
#            spherical fluid shell with gas interior  \
# frequency
# 12000.0                                     -42.80
# 14000.0                                     -43.44
# 16000.0                                     -43.99
# 18000.0                                     -44.51
# 20000.0                                     -44.97
# ...                                            ...
# 392000.0                                    -46.88
# 394000.0                                    -46.78
# 396000.0                                    -46.75
# 398000.0                                    -46.99
# 400000.0                                    -46.94
#
#            spherical fluid shell with weakly scattering interior  \
# frequency
# 12000.0                                               -99.15
# 14000.0                                               -96.79
# 16000.0                                               -94.83
# 18000.0                                               -93.20
# 20000.0                                               -91.85
# ...                                                      ...
# 392000.0                                             -108.29
# 394000.0                                             -107.19
# 396000.0                                             -106.49
# 398000.0                                             -106.14
# 400000.0                                             -106.15
#
#            fixed rigid prolate spheroid  pressure release prolate spheroid  \
# frequency
# 12000.0                          -35.98                             -30.16
# 14000.0                          -33.83                             -30.02
# 16000.0                          -32.20                             -29.87
# 18000.0                          -30.97                             -29.70
# 20000.0                          -30.08                             -29.54
# ...                                 ...                                ...
# 392000.0                            NaN                                NaN
# 394000.0                            NaN                                NaN
# 396000.0                            NaN                                NaN
# 398000.0                            NaN                                NaN
# 400000.0                            NaN                                NaN
#
#            gas filled prolate spheroid  weakly scattering prolate spheroid  \
# frequency
# 12000.0                            NaN                              -87.05
# 14000.0                            NaN                              -84.71
# 16000.0                            NaN                              -82.78
# 18000.0                            NaN                              -81.19
# 20000.0                            NaN                              -79.87
# ...                                ...                                 ...
# 392000.0                           NaN                              -86.94
# 394000.0                           NaN                              -83.45
# 396000.0                           NaN                              -81.16
# 398000.0                           NaN                              -79.55
# 400000.0                           NaN                              -78.41
#
#            fixed rigid finite cylinder  pressure release finite cylinder  \
# frequency
# 12000.0                         -38.75                            -35.29
# 14000.0                         -36.83                            -34.93
# 16000.0                         -35.45                            -34.56
# 18000.0                         -34.51                            -34.17
# 20000.0                         -33.95                            -33.80
# ...                                ...                               ...
# 392000.0                        -21.74                            -21.86
# 394000.0                        -21.72                            -21.84
# 396000.0                        -21.70                            -21.82
# 398000.0                        -21.68                            -21.80
# 400000.0                        -21.65                            -21.77
#
#            gas filled finite cylinder  weakly scattering finite cylinder
# frequency
# 12000.0                        -35.30                             -89.79
# 14000.0                        -34.93                             -87.54
# 16000.0                        -34.56                             -85.73
# 18000.0                        -34.18                             -84.27
# 20000.0                        -33.81                             -83.12
# ...                               ...                                ...
# 392000.0                       -21.92                             -70.78
# 394000.0                       -21.83                             -70.14
# 396000.0                       -21.82                             -69.78
# 398000.0                       -21.79                             -69.68
# 400000.0                       -21.79                             -69.83
#
# [195 rows x 15 columns]

# %% [markdown]
# ## Creating the model parameters
#
# We can now get the model parameters and results for a given model in the Jech et al (2015) paper and run the same model using the echoSMs package and compare them. First step is to get the model parameters for a model - we choose the weakly scattering sphere for this example:

# %%
m = rm.parameters('weakly scattering sphere')
m
# Out:
# {'boundary_type': 'fluid filled',
#  'a': 0.01,
#  'medium_rho': 1026.8,
#  'medium_c': 1477.3,
#  'target_rho': 1028.9,
#  'target_c': 1480.3}

# %% [markdown]
# These parameters need to have an angle and frequency range added. We will use the frequencies from the Jech et al (2015) paper to make comparisons simplier.

# %%
bm_f, bm_ts = bm.freq_data('weakly scattering sphere')
m['f'] = bm_f
m['theta'] = 90
m
# Out:
# {'boundary_type': 'fluid filled',
#  'a': 0.01,
#  'medium_rho': 1026.8,
#  'medium_c': 1477.3,
#  'target_rho': 1028.9,
#  'target_c': 1480.3,
#  'f': array([ 12000.,  14000.,  16000.,  18000.,  20000.,  22000.,  24000.,
#          26000.,  28000.,  30000.,  32000.,  34000.,  36000.,  38000.,
#          40000.,  42000.,  44000.,  46000.,  48000.,  50000.,  52000.,
#          54000.,  56000.,  58000.,  60000.,  62000.,  64000.,  66000.,
#          68000.,  70000.,  72000.,  74000.,  76000.,  78000.,  80000.,
#          82000.,  84000.,  86000.,  88000.,  90000.,  92000.,  94000.,
#          96000.,  98000., 100000., 102000., 104000., 106000., 108000.,
#         110000., 112000., 114000., 116000., 118000., 120000., 122000.,
#         124000., 126000., 128000., 130000., 132000., 134000., 136000.,
#         138000., 140000., 142000., 144000., 146000., 148000., 150000.,
#         152000., 154000., 156000., 158000., 160000., 162000., 164000.,
#         166000., 168000., 170000., 172000., 174000., 176000., 178000.,
#         180000., 182000., 184000., 186000., 188000., 190000., 192000.,
#         194000., 196000., 198000., 200000., 202000., 204000., 206000.,
#         208000., 210000., 212000., 214000., 216000., 218000., 220000.,
#         222000., 224000., 226000., 228000., 230000., 232000., 234000.,
#         236000., 238000., 240000., 242000., 244000., 246000., 248000.,
#         250000., 252000., 254000., 256000., 258000., 260000., 262000.,
#         264000., 266000., 268000., 270000., 272000., 274000., 276000.,
#         278000., 280000., 282000., 284000., 286000., 288000., 290000.,
#         292000., 294000., 296000., 298000., 300000., 302000., 304000.,
#         306000., 308000., 310000., 312000., 314000., 316000., 318000.,
#         320000., 322000., 324000., 326000., 328000., 330000., 332000.,
#         334000., 336000., 338000., 340000., 342000., 344000., 346000.,
#         348000., 350000., 352000., 354000., 356000., 358000., 360000.,
#         362000., 364000., 366000., 368000., 370000., 372000., 374000.,
#         376000., 378000., 380000., 382000., 384000., 386000., 388000.,
#         390000., 392000., 394000., 396000., 398000., 400000.]),
#  'theta': 90}

# %% [markdown]
# ## Calculating target strength
#
# The reference model for a weakly scattering sphere was the model series solution, so we create an instance of that model in echoSMs and get it to calculate the target strength as per the parameters in ``m``.

# %%
mod = MSSModel()
ts = mod.calculate_ts(m)

# %% [markdown]
# ## Comparison to existing target strength
#
# These results can be compared to those from the Jech et al (2015) paper. We can also calculate the mean difference between the Jech values and those from the echoSMs calculations.

# %%
jech_index = np.mean(np.abs(ts - bm_ts))

fig, axs = plt.subplots(2, 1, sharex=True)

axs[0].plot(bm_f/1e3, ts, label='echoSMs')
axs[0].plot(bm_f/1e3, bm_ts, label='Benchmark')
axs[0].set_ylabel('TS re 1 m$^2$ [dB]')
axs[0].legend(frameon=False, fontsize=6)

axs[1].plot(bm_f/1e3, ts-bm_ts)
axs[1].set_xlabel('frequency (kHz)')
axs[1].set_ylabel(r'$\Delta$ TS [dB]')
axs[1].annotate(f'{jech_index:.2f} dB', (0.05, 0.80), xycoords='axes fraction',
                    backgroundcolor=[.8, .8, .8])
_ = plt.suptitle('Weakly scattering sphere')
