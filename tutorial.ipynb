# %% [markdown]
# ## Tutorial
# <a target="_blank" href="https://colab.research.google.com/github/ices-tools-dev/echoSMs/blob/main/docs/tutorial.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# This notebook provides an introductory tutorial for echoSMs.

# %%
# !pip install matplotlib echosms
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Collecting echosms
#   Downloading echosms-0.2.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from echosms) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from echosms) (1.13.1)
# Collecting spheroidalwavefunctions (from echosms)
#   Downloading spheroidalwavefunctions-0.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from echosms) (2.0.2)
# Collecting trimesh (from echosms)
#   Downloading trimesh-4.5.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from echosms) (2024.10.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->echosms) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->echosms) (2024.2)
# Downloading echosms-0.2.1-py3-none-any.whl (39 kB)
# Downloading spheroidalwavefunctions-0.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.9 MB/s eta 0:00:00
# Downloading trimesh-4.5.2-py3-none-any.whl (704 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 704.4/704.4 kB 18.7 MB/s eta 0:00:00
# Installing collected packages: trimesh, spheroidalwavefunctions, echosms
# Successfully installed echosms-0.2.1 spheroidalwavefunctions-0.1.1 trimesh-4.5.2

# %% [markdown]
# ## Imports
#
# We import the modal series solution model from echoSMs and the benchmark data and reference models.

# %%
from echosms import MSSModel, BenchmarkData, ReferenceModels
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Reference models
# The reference models in the Jech et al (2015) paper are available in the echoSMs package:

# %%
rm = ReferenceModels()
print('Available reference models are:\n')
print('\n'.join(rm.names()))
# Out:
# Available reference models are:
#
# fixed rigid sphere
# pressure release sphere
# gas filled sphere
# weakly scattering sphere
# spherical fluid shell with pressure release interior
# spherical fluid shell with gas interior
# spherical fluid shell with weakly scattering interior
# fixed rigid prolate spheroid
# pressure release prolate spheroid
# gas filled prolate spheroid
# weakly scattering prolate spheroid
# fixed rigid finite cylinder
# pressure release finite cylinder
# gas filled finite cylinder
# weakly scattering finite cylinder
# WC20 calibration sphere
# WC21 calibration sphere
# WC22 calibration sphere
# WC25 calibration sphere
# WC38.1 calibration sphere
# WC57.2 calibration sphere
# WC60 calibration sphere
# WC64 calibration sphere
# Cu13.7 calibration sphere
# Cu23 calibration sphere
# Cu32 calibration sphere
# Cu42 calibration sphere
# Cu45 calibration sphere
# Cu60 calibration sphere
# Cu63 calibration sphere
# Cu64 calibration sphere

# %% [markdown]
# ## Benchmark results
# Likewise, the results from the benchmark model runs in the Jech et al (2015) paper are available in the echoSMs package.

# %%
bm = BenchmarkData()
bmf = bm.freq_dataset  # this is a Pandas DataFrame
bmf
# Out:
#      frequency (kHz)  fixed rigid sphere  pressure release sphere  \
# 0                 12              -54.44                   -42.29
# 1                 14              -52.20                   -42.92
# 2                 16              -50.40                   -43.52
# 3                 18              -48.96                   -44.02
# 4                 20              -47.85                   -44.39
# ..               ...                 ...                      ...
# 190              392              -45.96                   -46.00
# 191              394              -45.86                   -46.00
# 192              396              -45.80                   -46.00
# 193              398              -45.80                   -46.00
# 194              400              -45.84                   -46.00
#
#      gas filled sphere  weakly scattering sphere  \
# 0               -42.34                   -103.95
# 1               -42.93                   -101.62
# 2               -43.52                    -99.69
# 3               -44.03                    -98.10
# 4               -44.40                    -96.79
# ..                 ...                       ...
# 190             -46.03                   -103.61
# 191             -45.96                   -100.25
# 192             -46.07                    -98.03
# 193             -45.96                    -96.47
# 194             -46.05                    -95.37
#
#      spherical fluid shell with pressure release interior  \
# 0                                               -42.83
# 1                                               -43.40
# 2                                               -43.96
# 3                                               -44.49
# 4                                               -44.94
# ..                                                 ...
# 190                                             -46.91
# 191                                             -46.91
# 192                                             -46.91
# 193                                             -46.91
# 194                                             -46.91
#
#      spherical fluid shell with gas interior  \
# 0                                     -42.80
# 1                                     -43.44
# 2                                     -43.99
# 3                                     -44.51
# 4                                     -44.97
# ..                                       ...
# 190                                   -46.88
# 191                                   -46.78
# 192                                   -46.75
# 193                                   -46.99
# 194                                   -46.94
#
#      spherical fluid shell with weakly scattering interior  \
# 0                                               -99.15
# 1                                               -96.79
# 2                                               -94.83
# 3                                               -93.20
# 4                                               -91.85
# ..                                                 ...
# 190                                            -108.29
# 191                                            -107.19
# 192                                            -106.49
# 193                                            -106.14
# 194                                            -106.15
#
#      fixed rigid prolate spheroid  pressure release prolate spheroid  \
# 0                          -35.98                             -30.16
# 1                          -33.83                             -30.02
# 2                          -32.20                             -29.87
# 3                          -30.97                             -29.70
# 4                          -30.08                             -29.54
# ..                            ...                                ...
# 190                           NaN                                NaN
# 191                           NaN                                NaN
# 192                           NaN                                NaN
# 193                           NaN                                NaN
# 194                           NaN                                NaN
#
#      gas filled prolate spheroid  weakly scattering prolate spheroid  \
# 0                            NaN                              -87.05
# 1                            NaN                              -84.71
# 2                            NaN                              -82.78
# 3                            NaN                              -81.19
# 4                            NaN                              -79.87
# ..                           ...                                 ...
# 190                          NaN                              -86.94
# 191                          NaN                              -83.45
# 192                          NaN                              -81.16
# 193                          NaN                              -79.55
# 194                          NaN                              -78.41
#
#      fixed rigid finite cylinder  pressure release finite cylinder  \
# 0                         -38.75                            -35.29
# 1                         -36.83                            -34.93
# 2                         -35.45                            -34.56
# 3                         -34.51                            -34.17
# 4                         -33.95                            -33.80
# ..                           ...                               ...
# 190                       -21.74                            -21.86
# 191                       -21.72                            -21.84
# 192                       -21.70                            -21.82
# 193                       -21.68                            -21.80
# 194                       -21.65                            -21.77
#
#      gas filled finite cylinder  weakly scattering finite cylinder
# 0                        -35.30                             -89.79
# 1                        -34.93                             -87.54
# 2                        -34.56                             -85.73
# 3                        -34.18                             -84.27
# 4                        -33.81                             -83.12
# ..                          ...                                ...
# 190                      -21.92                             -70.78
# 191                      -21.83                             -70.14
# 192                      -21.82                             -69.78
# 193                      -21.79                             -69.68
# 194                      -21.79                             -69.83
#
# [195 rows x 16 columns]

# %% [markdown]
# ## Creating the model parameters
#
# We can now get the model parameters and results for a given model in the Jech et al (2015) paper and run the same model using the echoSMs package and compare them. First step is to get the model parameters for a model - we choose the weakly scattering sphere for this example:

# %%
m = rm.parameters('weakly scattering sphere')
m
# Out:
# {'boundary_type': 'fluid filled',
#  'a': 0.01,
#  'medium_rho': 1026.8,
#  'medium_c': 1477.3,
#  'target_rho': 1028.9,
#  'target_c': 1480.3}

# %% [markdown]
# These parameters need to have an angle and frequency range added. We will use the frequencies from the Jech et al (2015) paper to make comparisons simplier.

# %%
m['f'] = bm.freq_dataset['frequency (kHz)']*1e3
m['theta'] = 90
m
# Out:
# {'boundary_type': 'fluid filled',
#  'a': 0.01,
#  'medium_rho': 1026.8,
#  'medium_c': 1477.3,
#  'target_rho': 1028.9,
#  'target_c': 1480.3,
#  'f': 0       12000.0
#  1       14000.0
#  2       16000.0
#  3       18000.0
#  4       20000.0
#           ...
#  190    392000.0
#  191    394000.0
#  192    396000.0
#  193    398000.0
#  194    400000.0
#  Name: frequency (kHz), Length: 195, dtype: float64,
#  'theta': 90}

# %% [markdown]
# ## Calculating target strength
#
# The reference model for a weakly scattering sphere was the model series solution, so we create an instance of that model in echoSMs and get it to calculate the target strength as per the parameters in ``m``.

# %%
mod = MSSModel()
ts = mod.calculate_ts(m)

# %% [markdown]
# ## Comparison to existing target strength
#
# These results can be compared to those from the Jech et al (2015) paper. We can also calculate the mean difference between the Jech values and those from the echoSMs calculations.

# %%
jech_index = np.mean(np.abs(ts - bmf['weakly scattering sphere']))

fig, axs = plt.subplots(2, 1, sharex=True)

axs[0].plot(m['f']/1e3, ts, label='echoSMs')
axs[0].plot(bmf['frequency (kHz)'], bmf['weakly scattering sphere'], label='Benchmark')
axs[0].set_ylabel('TS re 1 m$^2$ [dB]')
axs[0].legend(frameon=False, fontsize=6)

axs[1].plot(m['f']*1e-3, ts-bmf['weakly scattering sphere'])
axs[1].set_xlabel('frequency (kHz)')
axs[1].set_ylabel(r'$\Delta$ TS [dB]')
axs[1].annotate(f'{jech_index:.2f} dB', (0.05, 0.80), xycoords='axes fraction',
                    backgroundcolor=[.8, .8, .8])
_ = plt.suptitle('Weakly scattering sphere')
