# %% [markdown]
# # EchoSMS demonstration for WGFAST 2025 presentation
#
# This Jupyter notebook provides a brief demonstration of the echoSMs Python package and how it can be used to
# calculate the target strength of various objects.

# %%
# !pip install echosms
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
# Out:
# Requirement already satisfied: echosms in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (0.9.1)
# Requirement already satisfied: mapply in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from echosms) (0.1.26)
# Requirement already satisfied: numpy in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from echosms) (1.26.4)
# Requirement already satisfied: pandas in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from echosms) (2.2.2)
# Requirement already satisfied: scipy in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from echosms) (1.12.0)
# Requirement already satisfied: spheroidalwavefunctions in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from echosms) (0.0.1)
# Requirement already satisfied: tqdm in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from echosms) (4.67.1)
# Requirement already satisfied: trimesh in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from echosms) (4.6.5)
# Requirement already satisfied: xarray in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from echosms) (2025.3.0)
# Requirement already satisfied: pathos>=0.3.1 in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from mapply->echosms) (0.3.3)
# Requirement already satisfied: multiprocess in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from mapply->echosms) (0.70.17)
# Requirement already satisfied: psutil in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from mapply->echosms) (7.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from pandas->echosms) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from pandas->echosms) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from pandas->echosms) (2025.2)
# Requirement already satisfied: colorama in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from tqdm->echosms) (0.4.6)
# Requirement already satisfied: packaging>=23.2 in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from xarray->echosms) (24.2)
# Requirement already satisfied: ppft>=1.7.6.9 in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from pathos>=0.3.1->mapply->echosms) (1.7.6.9)
# Requirement already satisfied: dill>=0.3.9 in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from pathos>=0.3.1->mapply->echosms) (0.3.9)
# Requirement already satisfied: pox>=0.3.5 in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from pathos>=0.3.1->mapply->echosms) (0.3.5)
# Requirement already satisfied: six>=1.5 in c:\users\gavinmacaulay\miniforge3\envs\p311\lib\site-packages (from python-dateutil>=2.8.2->pandas->echosms) (1.17.0)

# %%
import echosms

from importlib.metadata import version
version('echosms')
# Out:
# '0.9.1'

# %% [markdown]
# ## Reference models and benchmark data
#
# EchoSMs contains the model parameters and benchmark results from the Jech et al. (2015) paper. These are a useful set of models definitions and TS values to test other model code against. There are also some other useful model definitions, such as calibration spheres.

# %%
ref = echosms.ReferenceModels()
ref.names()
# Out:
# ['fixed rigid sphere',
#  'pressure release sphere',
#  'gas filled sphere',
#  'weakly scattering sphere',
#  'spherical fluid shell with pressure release interior',
#  'spherical fluid shell with gas interior',
#  'spherical fluid shell with weakly scattering interior',
#  'fixed rigid prolate spheroid',
#  'pressure release prolate spheroid',
#  'gas filled prolate spheroid',
#  'weakly scattering prolate spheroid',
#  'fixed rigid finite cylinder',
#  'pressure release finite cylinder',
#  'gas filled finite cylinder',
#  'weakly scattering finite cylinder',
#  'WC20 calibration sphere',
#  'WC21 calibration sphere',
#  'WC22 calibration sphere',
#  'WC25 calibration sphere',
#  'WC38.1 calibration sphere',
#  'WC57.2 calibration sphere',
#  'WC60 calibration sphere',
#  'WC64 calibration sphere',
#  'Cu10.3 calibration sphere',
#  'Cu13.7 calibration sphere',
#  'Cu23 calibration sphere',
#  'Cu32 calibration sphere',
#  'Cu32.1 calibration sphere',
#  'Cu42 calibration sphere',
#  'Cu45 calibration sphere',
#  'Cu60 calibration sphere',
#  'Cu63 calibration sphere',
#  'Cu64 calibration sphere']

# %%
ref.specification('weakly scattering sphere')
# Out:
# {'name': 'weakly scattering sphere',
#  'shape': 'sphere',
#  'boundary_type': 'fluid filled',
#  'description': 'A sphere with a fluid-filled interior with similar density and sound speed to the surrounding medium',
#  'a': 0.01,
#  'medium_rho': 1026.8,
#  'medium_c': 1477.3,
#  'target_rho': 1028.9,
#  'target_c': 1480.3,
#  'source': 'https://doi.org/10.1121/1.4937607',
#  'benchmark_model': 'mss'}

# %% [markdown]
# ## Shapes from the literature
#
# EchoSMs also contains other fish model data - with the aim of easing access to historical datasets easier and facilitating testing of new model implementations. Cod A, B, C, and D are the model shapes used in the Clay & Horne (1992) KRM paper.

# %%
echosms.KRMdata().names()
# Out:
# ['Sardine',
#  'Cod',
#  'Bocaccio',
#  'LargemouthBass_620',
#  'LargemouthBass_620_Lateral',
#  'LargemouthBass_627',
#  'LargemouthBass_627_Lateral',
#  'StripedBass_205',
#  'StripedBass_205_Lateral',
#  'StripedBass_628',
#  'StripedBass_628_Lateral',
#  'ChannelCatfish_1086',
#  'ChannelCatfish_1086_Lateral',
#  'WhiteCatfish_185',
#  'WhiteCatfish_185_Lateral',
#  'BlackCrappie_236',
#  'BlackCrappie_236_Lateral',
#  'Sandfish_200_Female',
#  'Sandfish_175_Male',
#  'Corvina_20140317_001_Broadside',
#  'Corvina_20140317_008_Broadside',
#  'Corvina_20140331_003_Broadside',
#  'Corvina_20140331_005_Broadside',
#  'Corvina_20140331_008_Broadside',
#  'AtlanticMackerel_26.94cm',
#  'AtlanticMackerel_backbone_26.94cm',
#  'AtlanticMackerel_backboneSkull_26.94cm',
#  'AtlanticMackerel_19.52cm',
#  'AtlanticMackerel_backbone_19.52cm',
#  'AtlanticMackerel_backboneSkull_19.52cm',
#  'SkipjackTuna_46.54cm',
#  'SkipjackTuna_backbone_46.54cm',
#  'SkipjackTuna_backboneSkull_46.54cm',
#  'SkipjackTuna_41.18cm',
#  'SkipjackTuna_backbone_41.18cm',
#  'SkipjackTuna_backboneSkull_41.18cm']

# %%
echosms.KRMdata().model('Cod').plot()

# %% [markdown]
# There are also some DWBA model shapes available from echoSMs:

# %%
echosms.DWBAdata().names()
# Out:
# ['Daphnia',
#  'Daphnia2',
#  'Generic acartia',
#  'Generic krill (Conti 2006)',
#  'Generic krill (McGehee 1998)',
#  'Nauplius',
#  'Sandeel']

# %%
echosms.DWBAdata().model('Generic krill (McGehee 1998)').plot()

# %% [markdown]
# ## Running models

# %%
parameters = echosms.ReferenceModels().parameters('spherical fluid shell with weakly scattering interior')
parameters['f'] = 38000
parameters
# Out:
# {'boundary_type': 'fluid shell fluid interior',
#  'a': 0.01,
#  'shell_thickness': 0.001,
#  'medium_rho': 1026.8,
#  'medium_c': 1477.3,
#  'shell_rho': 1028.9,
#  'shell_c': 1480.3,
#  'target_rho': 1031.0,
#  'target_c': 1483.3,
#  'f': 38000}

# %%
model = echosms.MSSModel()
model.calculate_ts(parameters)
# Out:
# [-88.24819006695961]

# %%
parameters['f'] = np.arange(1000, 400000, 500)
ts = model.calculate_ts(parameters, progress=True)
plt.plot(parameters['f']/1e3, ts);
# Out:
# mss: 100%|███████████████████████████████████████████████████████████████████████████████████ [798/798; 92.86 models/s]

# %% [markdown]
# How does that compare to the Jech et al. benchmark values?

# %%
bm_f, bm_ts = echosms.BenchmarkData().freq_data('spherical fluid shell with weakly scattering interior')
plt.plot(parameters['f']/1e3, ts, '-', bm_f/1e3, bm_ts, '+')
plt.legend(['echoSMs', 'benchmark']);

# %% [markdown]
# Can also have multiple parameter arrays, for example radius and frequency:

# %%
parameters['a'] = np.linspace(0.01, 0.025, 100)
parameters['f'] = np.linspace(10, 200, 100)*1e3
parameters
# Out:
# {'boundary_type': 'fluid shell fluid interior',
#  'a': array([0.01      , 0.01015152, 0.01030303, 0.01045455, 0.01060606,
#         0.01075758, 0.01090909, 0.01106061, 0.01121212, 0.01136364,
#         0.01151515, 0.01166667, 0.01181818, 0.0119697 , 0.01212121,
#         0.01227273, 0.01242424, 0.01257576, 0.01272727, 0.01287879,
#         0.0130303 , 0.01318182, 0.01333333, 0.01348485, 0.01363636,
#         0.01378788, 0.01393939, 0.01409091, 0.01424242, 0.01439394,
#         0.01454545, 0.01469697, 0.01484848, 0.015     , 0.01515152,
#         0.01530303, 0.01545455, 0.01560606, 0.01575758, 0.01590909,
#         0.01606061, 0.01621212, 0.01636364, 0.01651515, 0.01666667,
#         0.01681818, 0.0169697 , 0.01712121, 0.01727273, 0.01742424,
#         0.01757576, 0.01772727, 0.01787879, 0.0180303 , 0.01818182,
#         0.01833333, 0.01848485, 0.01863636, 0.01878788, 0.01893939,
#         0.01909091, 0.01924242, 0.01939394, 0.01954545, 0.01969697,
#         0.01984848, 0.02      , 0.02015152, 0.02030303, 0.02045455,
#         0.02060606, 0.02075758, 0.02090909, 0.02106061, 0.02121212,
#         0.02136364, 0.02151515, 0.02166667, 0.02181818, 0.0219697 ,
#         0.02212121, 0.02227273, 0.02242424, 0.02257576, 0.02272727,
#         0.02287879, 0.0230303 , 0.02318182, 0.02333333, 0.02348485,
#         0.02363636, 0.02378788, 0.02393939, 0.02409091, 0.02424242,
#         0.02439394, 0.02454545, 0.02469697, 0.02484848, 0.025     ]),
#  'shell_thickness': 0.001,
#  'medium_rho': 1026.8,
#  'medium_c': 1477.3,
#  'shell_rho': 1028.9,
#  'shell_c': 1480.3,
#  'target_rho': 1031.0,
#  'target_c': 1483.3,
#  'f': array([ 10000.        ,  11919.19191919,  13838.38383838,  15757.57575758,
#          17676.76767677,  19595.95959596,  21515.15151515,  23434.34343434,
#          25353.53535354,  27272.72727273,  29191.91919192,  31111.11111111,
#          33030.3030303 ,  34949.49494949,  36868.68686869,  38787.87878788,
#          40707.07070707,  42626.26262626,  44545.45454545,  46464.64646465,
#          48383.83838384,  50303.03030303,  52222.22222222,  54141.41414141,
#          56060.60606061,  57979.7979798 ,  59898.98989899,  61818.18181818,
#          63737.37373737,  65656.56565657,  67575.75757576,  69494.94949495,
#          71414.14141414,  73333.33333333,  75252.52525253,  77171.71717172,
#          79090.90909091,  81010.1010101 ,  82929.29292929,  84848.48484848,
#          86767.67676768,  88686.86868687,  90606.06060606,  92525.25252525,
#          94444.44444444,  96363.63636364,  98282.82828283, 100202.02020202,
#         102121.21212121, 104040.4040404 , 105959.5959596 , 107878.78787879,
#         109797.97979798, 111717.17171717, 113636.36363636, 115555.55555556,
#         117474.74747475, 119393.93939394, 121313.13131313, 123232.32323232,
#         125151.51515152, 127070.70707071, 128989.8989899 , 130909.09090909,
#         132828.28282828, 134747.47474747, 136666.66666667, 138585.85858586,
#         140505.05050505, 142424.24242424, 144343.43434343, 146262.62626263,
#         148181.81818182, 150101.01010101, 152020.2020202 , 153939.39393939,
#         155858.58585859, 157777.77777778, 159696.96969697, 161616.16161616,
#         163535.35353535, 165454.54545455, 167373.73737374, 169292.92929293,
#         171212.12121212, 173131.31313131, 175050.50505051, 176969.6969697 ,
#         178888.88888889, 180808.08080808, 182727.27272727, 184646.46464646,
#         186565.65656566, 188484.84848485, 190404.04040404, 192323.23232323,
#         194242.42424242, 196161.61616162, 198080.80808081, 200000.        ])}

# %% [markdown]
# These parameters define 10,000 model runs, so use the multiprocessing option to spread the calculations across CPU's

# %%
data = echosms.as_dataarray(parameters)
model.calculate_ts(data, progress=True, multiprocess=True)
# Out:
#   0%|                                                                                          | 0/100 [00:00<…

# %%
xr.plot.pcolormesh(data.squeeze(drop=True));

# %% [markdown]
# ## Summary
# EchoSMs offers:
# - Easy access to reference models, benchmark results, and other datasets
# - 9+ scattering models
# - Simple and consistent interface
