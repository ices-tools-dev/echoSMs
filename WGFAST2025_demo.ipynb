# %%
# !pip install echosms
# Out:
# Requirement already satisfied: echosms in /usr/local/lib/python3.11/dist-packages (0.9.0)
# Requirement already satisfied: mapply in /usr/local/lib/python3.11/dist-packages (from echosms) (0.1.27)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from echosms) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from echosms) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from echosms) (1.14.1)
# Requirement already satisfied: spheroidalwavefunctions in /usr/local/lib/python3.11/dist-packages (from echosms) (0.1.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from echosms) (4.67.1)
# Requirement already satisfied: trimesh in /usr/local/lib/python3.11/dist-packages (from echosms) (4.6.5)
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (from echosms) (2025.1.2)
# Requirement already satisfied: pathos>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from mapply->echosms) (0.3.3)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from mapply->echosms) (0.70.17)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from mapply->echosms) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->echosms) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->echosms) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->echosms) (2025.1)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from xarray->echosms) (24.2)
# Requirement already satisfied: ppft>=1.7.6.9 in /usr/local/lib/python3.11/dist-packages (from pathos>=0.3.1->mapply->echosms) (1.7.6.9)
# Requirement already satisfied: dill>=0.3.9 in /usr/local/lib/python3.11/dist-packages (from pathos>=0.3.1->mapply->echosms) (0.3.9)
# Requirement already satisfied: pox>=0.3.5 in /usr/local/lib/python3.11/dist-packages (from pathos>=0.3.1->mapply->echosms) (0.3.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->echosms) (1.17.0)

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

import echosms

# %% [markdown]
# ## Reference models and benchmark data
#
# EchoSMS contains the model parameters and benchmark results from the Jech et al. (2015) paper. These are a useful set of model parameters for testing models against. There are also some other useful model parameters.

# %%
ref = echosms.ReferenceModels()
ref.names()
# Out:
# ['fixed rigid sphere',
#  'pressure release sphere',
#  'gas filled sphere',
#  'weakly scattering sphere',
#  'spherical fluid shell with pressure release interior',
#  'spherical fluid shell with gas interior',
#  'spherical fluid shell with weakly scattering interior',
#  'fixed rigid prolate spheroid',
#  'pressure release prolate spheroid',
#  'gas filled prolate spheroid',
#  'weakly scattering prolate spheroid',
#  'fixed rigid finite cylinder',
#  'pressure release finite cylinder',
#  'gas filled finite cylinder',
#  'weakly scattering finite cylinder',
#  'WC20 calibration sphere',
#  'WC21 calibration sphere',
#  'WC22 calibration sphere',
#  'WC25 calibration sphere',
#  'WC38.1 calibration sphere',
#  'WC57.2 calibration sphere',
#  'WC60 calibration sphere',
#  'WC64 calibration sphere',
#  'Cu10.3 calibration sphere',
#  'Cu13.7 calibration sphere',
#  'Cu23 calibration sphere',
#  'Cu32 calibration sphere',
#  'Cu32.1 calibration sphere',
#  'Cu42 calibration sphere',
#  'Cu45 calibration sphere',
#  'Cu60 calibration sphere',
#  'Cu63 calibration sphere',
#  'Cu64 calibration sphere']

# %% [markdown]
# The specificiations for each of these models are available:

# %%
ref.specification('weakly scattering sphere')
# Out:
# {'name': 'weakly scattering sphere',
#  'shape': 'sphere',
#  'boundary_type': 'fluid filled',
#  'description': 'A sphere with a fluid-filled interior with similar density and sound speed to the surrounding medium',
#  'a': 0.01,
#  'medium_rho': 1026.8,
#  'medium_c': 1477.3,
#  'target_rho': 1028.9,
#  'target_c': 1480.3,
#  'source': 'https://doi.org/10.1121/1.4937607',
#  'benchmark_model': 'mss'}

# %% [markdown]
# ## Running a model
#
# A model that simulates a weakly scattering sphere is the Modal Series Solution model, which was used in the Jech paper as the benchmark model for weakly scattering spheres. That model can be run on the specification like this:

# %%
model = echosms.MSSModel()
parameters = ref.parameters('weakly scattering sphere')
parameters
# Out:
# {'boundary_type': 'fluid filled',
#  'a': 0.01,
#  'medium_rho': 1026.8,
#  'medium_c': 1477.3,
#  'target_rho': 1028.9,
#  'target_c': 1480.3}

# %% [markdown]
# The documentation for the MSS model shows that a 'f' parameter is also needed, so add that:

# %%
parameters['f'] = 38000

# %% [markdown]
# And then the model can be run with those parameters

# %%
model.calculate_ts(parameters)
# Out:
# [-94.13445487634077]

# %% [markdown]
# Multiple sets of parameters can be run with one call:

# %%
parameters['f'] = range(1000, 400000, 500)
ts = model.calculate_ts(parameters, progress=True)
# Out:
# mss: 100%|██████████ [798/798; 815.04 models/s]

# %%
plt.plot(parameters['f'], ts)

# %% [markdown]
# And how does that compare to the results in Jech et al?. Those data are also in echoSMs:

# %%
bm_f, bm_ts = echosms.BenchmarkData().freq_data('weakly scattering sphere')
plt.plot(parameters['f'], ts, bm_f, bm_ts)
plt.legend(['echoSMs', 'benchmark'])

# %% [markdown]
# Sometimes one wants to run the model with multiple combinations of parameters. This is easily done:

# %%
parameters['a'] = np.linspace(0.001, 0.025, 100)
parameters['f'] = np.linspace(10, 200, 100)*1e3
parameters
# Out:
# {'boundary_type': 'fluid filled',
#  'a': array([0.001     , 0.00124242, 0.00148485, 0.00172727, 0.0019697 ,
#         0.00221212, 0.00245455, 0.00269697, 0.00293939, 0.00318182,
#         0.00342424, 0.00366667, 0.00390909, 0.00415152, 0.00439394,
#         0.00463636, 0.00487879, 0.00512121, 0.00536364, 0.00560606,
#         0.00584848, 0.00609091, 0.00633333, 0.00657576, 0.00681818,
#         0.00706061, 0.00730303, 0.00754545, 0.00778788, 0.0080303 ,
#         0.00827273, 0.00851515, 0.00875758, 0.009     , 0.00924242,
#         0.00948485, 0.00972727, 0.0099697 , 0.01021212, 0.01045455,
#         0.01069697, 0.01093939, 0.01118182, 0.01142424, 0.01166667,
#         0.01190909, 0.01215152, 0.01239394, 0.01263636, 0.01287879,
#         0.01312121, 0.01336364, 0.01360606, 0.01384848, 0.01409091,
#         0.01433333, 0.01457576, 0.01481818, 0.01506061, 0.01530303,
#         0.01554545, 0.01578788, 0.0160303 , 0.01627273, 0.01651515,
#         0.01675758, 0.017     , 0.01724242, 0.01748485, 0.01772727,
#         0.0179697 , 0.01821212, 0.01845455, 0.01869697, 0.01893939,
#         0.01918182, 0.01942424, 0.01966667, 0.01990909, 0.02015152,
#         0.02039394, 0.02063636, 0.02087879, 0.02112121, 0.02136364,
#         0.02160606, 0.02184848, 0.02209091, 0.02233333, 0.02257576,
#         0.02281818, 0.02306061, 0.02330303, 0.02354545, 0.02378788,
#         0.0240303 , 0.02427273, 0.02451515, 0.02475758, 0.025     ]),
#  'medium_rho': 1026.8,
#  'medium_c': 1477.3,
#  'target_rho': 1028.9,
#  'target_c': 1480.3,
#  'f': array([ 10000.        ,  11919.19191919,  13838.38383838,  15757.57575758,
#          17676.76767677,  19595.95959596,  21515.15151515,  23434.34343434,
#          25353.53535354,  27272.72727273,  29191.91919192,  31111.11111111,
#          33030.3030303 ,  34949.49494949,  36868.68686869,  38787.87878788,
#          40707.07070707,  42626.26262626,  44545.45454545,  46464.64646465,
#          48383.83838384,  50303.03030303,  52222.22222222,  54141.41414141,
#          56060.60606061,  57979.7979798 ,  59898.98989899,  61818.18181818,
#          63737.37373737,  65656.56565657,  67575.75757576,  69494.94949495,
#          71414.14141414,  73333.33333333,  75252.52525253,  77171.71717172,
#          79090.90909091,  81010.1010101 ,  82929.29292929,  84848.48484848,
#          86767.67676768,  88686.86868687,  90606.06060606,  92525.25252525,
#          94444.44444444,  96363.63636364,  98282.82828283, 100202.02020202,
#         102121.21212121, 104040.4040404 , 105959.5959596 , 107878.78787879,
#         109797.97979798, 111717.17171717, 113636.36363636, 115555.55555556,
#         117474.74747475, 119393.93939394, 121313.13131313, 123232.32323232,
#         125151.51515152, 127070.70707071, 128989.8989899 , 130909.09090909,
#         132828.28282828, 134747.47474747, 136666.66666667, 138585.85858586,
#         140505.05050505, 142424.24242424, 144343.43434343, 146262.62626263,
#         148181.81818182, 150101.01010101, 152020.2020202 , 153939.39393939,
#         155858.58585859, 157777.77777778, 159696.96969697, 161616.16161616,
#         163535.35353535, 165454.54545455, 167373.73737374, 169292.92929293,
#         171212.12121212, 173131.31313131, 175050.50505051, 176969.6969697 ,
#         178888.88888889, 180808.08080808, 182727.27272727, 184646.46464646,
#         186565.65656566, 188484.84848485, 190404.04040404, 192323.23232323,
#         194242.42424242, 196161.61616162, 198080.80808081, 200000.        ])}

# %%
data = echosms.as_dataarray(parameters)
ts = model.calculate_ts(data, progress=True, multiprocess=True, expand=True)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]

# %%
data['f'] = data.f/1e3

# %% [markdown]
# These data are nicer plotted as an image:

# %%
xr.plot.pcolormesh(data.squeeze(drop=True))

# %% [markdown]
# For convenience, the model definitions for all known calibration spheres is in echoSMs

# %%
ref.names()
# Out:
# ['fixed rigid sphere',
#  'pressure release sphere',
#  'gas filled sphere',
#  'weakly scattering sphere',
#  'spherical fluid shell with pressure release interior',
#  'spherical fluid shell with gas interior',
#  'spherical fluid shell with weakly scattering interior',
#  'fixed rigid prolate spheroid',
#  'pressure release prolate spheroid',
#  'gas filled prolate spheroid',
#  'weakly scattering prolate spheroid',
#  'fixed rigid finite cylinder',
#  'pressure release finite cylinder',
#  'gas filled finite cylinder',
#  'weakly scattering finite cylinder',
#  'WC20 calibration sphere',
#  'WC21 calibration sphere',
#  'WC22 calibration sphere',
#  'WC25 calibration sphere',
#  'WC38.1 calibration sphere',
#  'WC57.2 calibration sphere',
#  'WC60 calibration sphere',
#  'WC64 calibration sphere',
#  'Cu10.3 calibration sphere',
#  'Cu13.7 calibration sphere',
#  'Cu23 calibration sphere',
#  'Cu32 calibration sphere',
#  'Cu32.1 calibration sphere',
#  'Cu42 calibration sphere',
#  'Cu45 calibration sphere',
#  'Cu60 calibration sphere',
#  'Cu63 calibration sphere',
#  'Cu64 calibration sphere']

# %%
wc381 = ref.parameters('WC38.1 calibration sphere')
wc381['f'] = np.linspace(55, 100, 100)*1e3
wc381
# Out:
# {'boundary_type': 'elastic',
#  'a': 0.01905,
#  'medium_rho': 1026.8,
#  'medium_c': 1477.3,
#  'target_rho': 14900,
#  'target_longitudinal_c': 6853,
#  'target_transverse_c': 4171,
#  'f': array([ 55000.        ,  55454.54545455,  55909.09090909,  56363.63636364,
#          56818.18181818,  57272.72727273,  57727.27272727,  58181.81818182,
#          58636.36363636,  59090.90909091,  59545.45454545,  60000.        ,
#          60454.54545455,  60909.09090909,  61363.63636364,  61818.18181818,
#          62272.72727273,  62727.27272727,  63181.81818182,  63636.36363636,
#          64090.90909091,  64545.45454545,  65000.        ,  65454.54545455,
#          65909.09090909,  66363.63636364,  66818.18181818,  67272.72727273,
#          67727.27272727,  68181.81818182,  68636.36363636,  69090.90909091,
#          69545.45454545,  70000.        ,  70454.54545455,  70909.09090909,
#          71363.63636364,  71818.18181818,  72272.72727273,  72727.27272727,
#          73181.81818182,  73636.36363636,  74090.90909091,  74545.45454545,
#          75000.        ,  75454.54545455,  75909.09090909,  76363.63636364,
#          76818.18181818,  77272.72727273,  77727.27272727,  78181.81818182,
#          78636.36363636,  79090.90909091,  79545.45454545,  80000.        ,
#          80454.54545455,  80909.09090909,  81363.63636364,  81818.18181818,
#          82272.72727273,  82727.27272727,  83181.81818182,  83636.36363636,
#          84090.90909091,  84545.45454545,  85000.        ,  85454.54545455,
#          85909.09090909,  86363.63636364,  86818.18181818,  87272.72727273,
#          87727.27272727,  88181.81818182,  88636.36363636,  89090.90909091,
#          89545.45454545,  90000.        ,  90454.54545455,  90909.09090909,
#          91363.63636364,  91818.18181818,  92272.72727273,  92727.27272727,
#          93181.81818182,  93636.36363636,  94090.90909091,  94545.45454545,
#          95000.        ,  95454.54545455,  95909.09090909,  96363.63636364,
#          96818.18181818,  97272.72727273,  97727.27272727,  98181.81818182,
#          98636.36363636,  99090.90909091,  99545.45454545, 100000.        ])}

# %%
model = echosms.ESModel()
ts = model.calculate_ts(wc381, progress=True)
plt.plot(wc381['f'], ts)
# Out:
# es: 100%|██████████ [100/100; 843.19 models/s]

# %% [markdown]
# ## Historical organism shapes
#
# EchoSMs also contains other fish model data - with the aim of making access to historical datasets more widely available and to enable testing of new model implementations. The example below shows the Clay & Horne KRM cod TS model. EchoSMs also contains similar model data for some published DWBA models. These data have all come from publically-available datasets and are collected in echoSMs to provide a single convenient place to access these data.

# %%
echosms.KRMdata().names()
# Out:
# ['Sardine',
#  'Cod',
#  'Bocaccio',
#  'LargemouthBass_620',
#  'LargemouthBass_620_Lateral',
#  'LargemouthBass_627',
#  'LargemouthBass_627_Lateral',
#  'StripedBass_205',
#  'StripedBass_205_Lateral',
#  'StripedBass_628',
#  'StripedBass_628_Lateral',
#  'ChannelCatfish_1086',
#  'ChannelCatfish_1086_Lateral',
#  'WhiteCatfish_185',
#  'WhiteCatfish_185_Lateral',
#  'BlackCrappie_236',
#  'BlackCrappie_236_Lateral',
#  'Sandfish_200_Female',
#  'Sandfish_175_Male',
#  'Corvina_20140317_001_Broadside',
#  'Corvina_20140317_008_Broadside',
#  'Corvina_20140331_003_Broadside',
#  'Corvina_20140331_005_Broadside',
#  'Corvina_20140331_008_Broadside',
#  'AtlanticMackerel_26.94cm',
#  'AtlanticMackerel_backbone_26.94cm',
#  'AtlanticMackerel_backboneSkull_26.94cm',
#  'AtlanticMackerel_19.52cm',
#  'AtlanticMackerel_backbone_19.52cm',
#  'AtlanticMackerel_backboneSkull_19.52cm',
#  'SkipjackTuna_46.54cm',
#  'SkipjackTuna_backbone_46.54cm',
#  'SkipjackTuna_backboneSkull_46.54cm',
#  'SkipjackTuna_41.18cm',
#  'SkipjackTuna_backbone_41.18cm',
#  'SkipjackTuna_backboneSkull_41.18cm']

# %% [markdown]
# The cod shape is what was used in the Clay & Horne paper:

# %%
cod = echosms.KRMdata().model('Cod')
cod.plot()

# %% [markdown]
# The echoSMs implementation of the KRM model can be run using these shape data:

# %%
p = {'medium_c': 1490, 'medium_rho': 1030, 'organism': cod, 'theta': 90,
         'f': np.arange(12, 121, .1)*1e3}

# %%
model = echosms.KRMModel()
krm_ts = model.calculate_ts(p)

# %%
plt.plot(p['f']/1e3, krm_ts)
plt.xlabel('Freq')
plt.ylabel('TS')
# Out:
# Text(0, 0.5, 'TS')

# %% [markdown]
# The DWBA models in echoSMs are

# %%
echosms.DWBAdata().names()
# Out:
# ['Daphnia',
#  'Daphnia2',
#  'Generic acartia',
#  'Generic krill (Conti 2006)',
#  'Generic krill (McGehee 1998)',
#  'Nauplius',
#  'Sandeel']

# %%
krill = echosms.DWBAdata().model('Generic krill (McGehee 1998)')

# %%
krill.source
# Out:
# 'https://doi.org/10.1016/S0967-0645(98)00036-8'

# %%
krill.plot()
